# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
# read movie metadata
movie_md = pd.read_csv('./data/movies_metadata.csv', low_memory=False)

# %%
df = movie_md.copy()
df.shape
# Out:
# (45466, 24)

# %%
df.describe()
# Out:
#             revenue       runtime  vote_average    vote_count
# count  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   1.120935e+07     94.128199      5.618207    109.897338
# std    6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00    107.000000      6.800000     34.000000
# max    2.787965e+09   1256.000000     10.000000  14075.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
# adult                    45466 non-null object
# belongs_to_collection    4494 non-null object
# budget                   45466 non-null object
# genres                   45466 non-null object
# homepage                 7782 non-null object
# id                       45466 non-null object
# imdb_id                  45449 non-null object
# original_language        45455 non-null object
# original_title           45466 non-null object
# overview                 44512 non-null object
# popularity               45461 non-null object
# poster_path              45080 non-null object
# production_companies     45463 non-null object
# production_countries     45463 non-null object
# release_date             45379 non-null object
# revenue                  45460 non-null float64
# runtime                  45203 non-null float64
# spoken_languages         45460 non-null object
# status                   45379 non-null object
# tagline                  20412 non-null object
# title                    45460 non-null object
# video                    45460 non-null object
# vote_average             45460 non-null float64
# vote_count               45460 non-null float64
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB

# %%
df.head(2)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                homepage    id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story   862  tt0114709                en
# 1                                   NaN  8844  tt0113497                en
#
#   original_title                                           overview  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...
# 1        Jumanji  When siblings Judy and Peter discover an encha...
#
#      ...     release_date      revenue runtime  \
# 0    ...       1995-10-30  373554033.0    81.0
# 1    ...       1995-12-15  262797249.0   104.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                      tagline      title  video vote_average  \
# 0                                        NaN  Toy Story  False          7.7
# 1  Roll the dice and unleash the excitement!    Jumanji  False          6.9
#
#   vote_count
# 0     5415.0
# 1     2413.0
#
# [2 rows x 24 columns]

# %%
from ast import literal_eval
def process_genres(df):
    '''
    process genres column using liter_eval to convert string to python object
    extract the genres info
    '''
    df['genres'] = df['genres'].fillna('[]').apply(literal_eval)
    # extract the 'name' value of genres
    df['genres'] = df['genres'].apply(lambda x: [i['name'] for i in x])
    
print('before processing genres: \n', df['genres'][0])
process_genres(df)
print('after processeding genres: \n', df['genres'][0])
# Out:
# before processing genres:
#  [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]
# after processeding genres:
#  ['Animation', 'Comedy', 'Family']

# %%
# process release_date to show year only
df['year'] = df['release_date'].apply(lambda x: str(x)[:4] if x != 'NaN' else np.nan)
print('the release_data column:')
print(df['release_date'].head())
print('the year column:')
print(df['year'].head())
# Out:
# the release_data column:
# 0    1995-10-30
# 1    1995-12-15
# 2    1995-12-22
# 3    1995-12-22
# 4    1995-02-10
# Name: release_date, dtype: object
# the year column:
# 0    1995
# 1    1995
# 2    1995
# 3    1995
# 4    1995
# Name: year, dtype: object

# %%
def process_vote(df, vote_count_cutoff_percentile=0.95):
    '''
    calculate weighted rating instead of row rating
    weighted rating (WR) = (v ÷ (v+m)) × R + (m ÷ (v+m)) × C

    Where: 
    R = average for the movie (mean) = (rating)
    v = number of votes for the movie = (votes)
    m = minimum votes required to be listed in the Top Rated list (default: 95 percentile of vote_count)
    C = the mean vote across the whole report
    '''
    df = df.dropna(subset=['vote_count', 'vote_average'])
    df.vote_count = df.vote_count.astype('int')
    df.vote_average = df.vote_average.astype('int')
    
    mean_vote_average = df.vote_average.mean()
    vote_count_cutoff = df.vote_count.quantile(vote_count_cutoff_percentile)
    df = df.loc[df['vote_count'] >= vote_count_cutoff]
    df['weighted_rating'] = (df.vote_average * df.vote_count/(df.vote_count + vote_count_cutoff)) + \
                            (mean_vote_average * vote_count_cutoff/(df.vote_count + vote_count_cutoff))
    df = df.sort_values('weighted_rating', ascending=False)
    return df

# %%
df = process_vote(df)
# Out:
# /Users/JCChiang/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
FEATURES = ['title', 'year', 'vote_count', 'vote_average', 'popularity', \
            'genres', 'weighted_rating', 'tagline', 'overview', 'id']
df = df[FEATURES]
df.shape
# Out:
# (2274, 10)

# %%
def get_tops_by_genres(df, *genres, intersect=True, top=10):
    if not genres:
        return df.head(top)
    elif not intersect:
        return df[df['genres'].apply(lambda x: not set(genres).isdisjoint(x))].head(top)
    else:
        return df[df['genres'].apply(lambda x: set(genres).issubset(x))].head(top)

# %%
get_tops_by_genres(df, 'Family').head()
# Out:
#                       title  year  vote_count  vote_average popularity  \
# 1225     Back to the Future  1985        6239             8  25.778509
# 359           The Lion King  1994        5520             8  21.605761
# 5481          Spirited Away  2001        3968             8  41.048867
# 5833     My Neighbor Totoro  1988        1730             8  13.507299
# 926   It's a Wonderful Life  1946        1103             8  15.031588
#
#                                             genres  weighted_rating  \
# 1225  [Adventure, Comedy, Science Fiction, Family]         7.820813
# 359                     [Family, Animation, Drama]         7.799175
# 5481       [Fantasy, Adventure, Animation, Family]         7.728370
# 5833                  [Fantasy, Animation, Family]         7.447452
# 926                       [Drama, Family, Fantasy]         7.222046
#
#                                                 tagline  \
# 1225  He's the only kid ever to get into trouble bef...
# 359   Life's greatest adventure is finding your plac...
# 5481     The tunnel led Chihiro to a mysterious town...
# 5833  These strange creatures still exist in Japan. ...
# 926      It's a wonderful laugh! It's a wonderful love!
#
#                                                overview    id
# 1225  Eighties teenager Marty McFly is accidentally ...   105
# 359   A young lion cub named Simba can't wait to be ...  8587
# 5481  A ten year old girl who wanders away from her ...   129
# 5833  Two sisters move to the country with their fat...  8392
# 926   George Bailey has spent his entire life giving...  1585

# %%
get_tops_by_genres(df, 'Family', 'Animation').head()
# Out:
#                     title  year  vote_count  vote_average popularity  \
# 359         The Lion King  1994        5520             8  21.605761
# 5481        Spirited Away  2001        3968             8  41.048867
# 5833   My Neighbor Totoro  1988        1730             8  13.507299
# 19901            Paperman  2012         734             8   7.198633
# 13724                  Up  2009        7048             7  19.330884
#
#                                         genres  weighted_rating  \
# 359                 [Family, Animation, Drama]         7.799175
# 5481   [Fantasy, Adventure, Animation, Family]         7.728370
# 5833              [Fantasy, Animation, Family]         7.447452
# 19901             [Animation, Family, Romance]         6.976272
# 13724   [Animation, Comedy, Family, Adventure]         6.898194
#
#                                                  tagline  \
# 359    Life's greatest adventure is finding your plac...
# 5481      The tunnel led Chihiro to a mysterious town...
# 5833   These strange creatures still exist in Japan. ...
# 19901                      Delicate, charming and sweet.
# 13724                                                NaN
#
#                                                 overview      id
# 359    A young lion cub named Simba can't wait to be ...    8587
# 5481   A ten year old girl who wanders away from her ...     129
# 5833   Two sisters move to the country with their fat...    8392
# 19901  An urban office worker finds that paper airpla...  140420
# 13724  Carl Fredricksen spent his entire life dreamin...   14160

# %%
get_tops_by_genres(df, 'Family', 'Animation', intersect=True).head()
# Out:
#                     title  year  vote_count  vote_average popularity  \
# 359         The Lion King  1994        5520             8  21.605761
# 5481        Spirited Away  2001        3968             8  41.048867
# 5833   My Neighbor Totoro  1988        1730             8  13.507299
# 19901            Paperman  2012         734             8   7.198633
# 13724                  Up  2009        7048             7  19.330884
#
#                                         genres  weighted_rating  \
# 359                 [Family, Animation, Drama]         7.799175
# 5481   [Fantasy, Adventure, Animation, Family]         7.728370
# 5833              [Fantasy, Animation, Family]         7.447452
# 19901             [Animation, Family, Romance]         6.976272
# 13724   [Animation, Comedy, Family, Adventure]         6.898194
#
#                                                  tagline  \
# 359    Life's greatest adventure is finding your plac...
# 5481      The tunnel led Chihiro to a mysterious town...
# 5833   These strange creatures still exist in Japan. ...
# 19901                      Delicate, charming and sweet.
# 13724                                                NaN
#
#                                                 overview      id
# 359    A young lion cub named Simba can't wait to be ...    8587
# 5481   A ten year old girl who wanders away from her ...     129
# 5833   Two sisters move to the country with their fat...    8392
# 19901  An urban office worker finds that paper airpla...  140420
# 13724  Carl Fredricksen spent his entire life dreamin...   14160

# %%
def get_tops_by_year(df, year, top=10):
    return df[df.year == str(year)].head(top)

# %%
get_tops_by_year(df,2013).head()
# Out:
#                                  title  year  vote_count  vote_average  \
# 22131          The Wolf of Wall Street  2013        6768             7
# 22058  The Hunger Games: Catching Fire  2013        6656             7
# 21592                          Gravity  2013        5879             7
# 21025                   Now You See Me  2013        5635             7
# 22110                           Frozen  2013        5440             7
#
#       popularity                                genres  weighted_rating  \
# 22131  16.382422                [Crime, Drama, Comedy]         6.894236
# 22058  25.309139  [Adventure, Action, Science Fiction]         6.892565
# 21592   18.50194    [Science Fiction, Thriller, Drama]         6.879342
# 21025  17.852022                     [Thriller, Crime]         6.874491
# 22110  24.248243        [Animation, Adventure, Family]         6.870324
#
#                                                  tagline  \
# 22131                                EARN. SPEND. PARTY.
# 22058              Every revolution begins with a spark.
# 21592                                       Don't Let Go
# 21025  4 amazing magicians. 3 impossible heists. 1 bi...
# 22110  Only the act of true love will thaw a frozen h...
#
#                                                 overview      id
# 22131  A New York stockbroker refuses to cooperate in...  106646
# 22058  Katniss Everdeen has returned home safe after ...  101299
# 21592  Dr. Ryan Stone, a brilliant medical engineer o...   49047
# 21025  An FBI agent and an Interpol detective track a...   75656
# 22110  Young princess Anna of Arendelle dreams about ...  109445

# %%
df.columns
# Out:
# Index(['title', 'year', 'vote_count', 'vote_average', 'popularity', 'genres',
#        'weighted_rating', 'tagline', 'overview', 'id'],
#       dtype='object')

# %%
# Content-based recommendation
df.tagline.fillna('', inplace=True)
df.overview.fillna('', inplace=True)

# %%
df['description'] = df.overview + df.tagline
df['description'].head(1).values
# Out:
# array(['Cobb, a skilled thief who commits corporate espionage by infiltrating the subconscious of his targets is offered a chance to regain his old life as payment for a task considered to be impossible: "inception", the implantation of another person\'s idea into a target\'s subconscious.Your mind is the scene of the crime.'],
#       dtype=object)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
def cal_similarity_matrix(data):    
    tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
    tfidf_matrix = tf.fit_transform(data)
    cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
    return cosine_sim

# %%
cosine_sim_description = cal_similarity_matrix(df['description'])

# %%
title_to_idx = {title: idx for title, idx in zip(df.title, range(df.shape[0]))}
title_to_idx['Inception']
# Out:
# 0

# %%
def get_recommendation_by_title(df, title, cosine_sim, top=10):
    idx = title_to_idx[title]
    scores = sorted(list(enumerate(cosine_sim[idx])), key=lambda x: x[1], reverse=True)
    movie_indices = list(map(lambda x: x[0], scores[1:top+1]))
    return df.iloc[movie_indices].sort_values('weighted_rating', ascending=False)

# %%
get_recommendation_by_title(df, 'Toy Story', cosine_sim_description).head()
# Out:
#                        title  year  vote_count  vote_average popularity  \
# 15348            Toy Story 3  2010        4710             7   16.96647
# 2997             Toy Story 2  1999        3914             7  17.547693
# 11007  The Devil Wears Prada  2006        3198             7  13.102384
# 10585            Match Point  2005        1134             7   9.020372
# 1199               Manhattan  1979         600             7  12.050759
#
#                                   genres  weighted_rating  \
# 15348        [Animation, Family, Comedy]         6.851922
# 2997         [Animation, Comedy, Family]         6.824813
# 11007           [Comedy, Drama, Romance]         6.790277
# 10585  [Drama, Thriller, Crime, Romance]         6.514212
# 1199            [Comedy, Drama, Romance]         6.263332
#
#                                                  tagline  \
# 15348                           No toy gets left behind.
# 2997                                  The toys are back!
# 11007  Meet Andy Sachs. A million girls would kill to...
# 10585                       Passion Temptation Obsession
# 1199                        Woody Allen's New Comedy Hit
#
#                                                 overview     id  \
# 15348  Woody, Buzz, and the rest of Andy's toys haven...  10193
# 2997   Andy heads off to Cowboy Camp, leaving his toy...    863
# 11007  The Devil Wears Prada is about a young journal...    350
# 10585  Match Point is Woody Allen’s satire of the Bri...    116
# 1199   The life of a divorced television writer datin...    696
#
#                                              description
# 15348  Woody, Buzz, and the rest of Andy's toys haven...
# 2997   Andy heads off to Cowboy Camp, leaving his toy...
# 11007  The Devil Wears Prada is about a young journal...
# 10585  Match Point is Woody Allen’s satire of the Bri...
# 1199   The life of a divorced television writer datin...

# %%
get_recommendation_by_title(df, 'The Dark Knight', cosine_sim_description).head()
# Out:
#                                     title  year  vote_count  vote_average  \
# 18252               The Dark Knight Rises  2012        9263             7
# 18258  Sherlock Holmes: A Game of Shadows  2011        3971             7
# 585                                Batman  1989        2145             7
# 14301                 Law Abiding Citizen  2009        1522             7
# 41976               The Lego Batman Movie  2017        1473             7
#
#       popularity                                        genres  \
# 18252   20.58258              [Action, Crime, Drama, Thriller]
# 18258  18.695329           [Adventure, Action, Crime, Mystery]
# 585     19.10673                             [Fantasy, Action]
# 14301  16.639047                      [Drama, Crime, Thriller]
# 41976  17.070748  [Action, Animation, Comedy, Family, Fantasy]
#
#        weighted_rating                                            tagline  \
# 18252         6.921448                                    The Legend Ends
# 18258         6.827079                                 The game is afoot.
# 585           6.704647  Have you ever danced with the devil in the pal...
# 14301         6.610575                               The System Must Pay.
# 41976         6.600569      Always be yourself. Unless you can be Batman.
#
#                                                 overview      id  \
# 18252  Following the death of District Attorney Harve...   49026
# 18258  There is a new criminal mastermind at large (P...   58574
# 585    The Dark Knight of Gotham City begins his war ...     268
# 14301  A frustrated man decides to take justice into ...   22803
# 41976  In the irreverent spirit of fun that made “The...  324849
#
#                                              description
# 18252  Following the death of District Attorney Harve...
# 18258  There is a new criminal mastermind at large (P...
# 585    The Dark Knight of Gotham City begins his war ...
# 14301  A frustrated man decides to take justice into ...
# 41976  In the irreverent spirit of fun that made “The...

# %%
# add more features to calculate similarity between movies
credits = pd.read_csv('./data/credits.csv')
keywords = pd.read_csv('./data/keywords.csv')

# remove duplicates
credits = credits.drop_duplicates(subset='id')
keywords = keywords.drop_duplicates(subset='id')

# %%
df['id'] = df['id'].astype(int)
df = df.merge(credits, on='id')
df = df.merge(keywords, on='id')

# %%
# extract names of the top 3 actors from the cast column
df['cast'] = df['cast'].fillna('[]').apply(lambda x: [str.lower(i['name'].replace(" ","")) for i in literal_eval(x)][:3])

# %%
def get_director(x):
    '''
    extract director's name from crew column of x
    '''
    for i in x:
        if i['job'] == 'Director':
            return str.lower(i['name'].replace(' ', ''))
    return np.nan

# %%
df['director'] = df['crew'].fillna('[]').apply(lambda x: get_director(literal_eval(x)))

# %%
# process keywords
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer('english')
df['keywords'] = df['keywords'].fillna('[]').apply(lambda x: [str.lower(stemmer.stem(i['name'].replace(' ', ''))) for i in literal_eval(x)])

# %%
df.head()[['cast', 'director', 'keywords']]
# Out:
#                                                 cast          director  \
# 0  [leonardodicaprio, josephgordon-levitt, ellenp...  christophernolan
# 1         [christianbale, michaelcaine, heathledger]  christophernolan
# 2  [matthewmcconaughey, jessicachastain, annehath...  christophernolan
# 3                 [edwardnorton, bradpitt, meatloaf]      davidfincher
# 4           [elijahwood, ianmckellen, cateblanchett]      peterjackson
#
#                                             keywords
# 0  [lossoflov, dream, kidnap, sleep, subconsci, h...
# 1  [dccomic, crimefight, secretident, scarecrow, ...
# 2  [savingtheworld, artificialintellig, fatherson...
# 3  [supportgroup, dualident, nihil, rageandh, ins...
# 4  [elv, dwarv, orc, middle-earth(tolkien), hobbi...

# %%
# use title, genres, top 3 actors, director (* 3 to make director a more significant factor), 
# and keyword to calculate similarity
df['mixed_credits'] = df['title'].apply(lambda x: [x]) + df['genres'] + df['cast'] + df['director'].apply(lambda x: [x]) * 3 + df['keywords']
print(df['mixed_credits'].head())
df['mixed_credits'] = df['mixed_credits'].apply(lambda x: ' '.join(x))
print(df['mixed_credits'].head())
# Out:
# 0    [Inception, Action, Thriller, Science Fiction,...
# 1    [The Dark Knight, Drama, Action, Crime, Thrill...
# 2    [Interstellar, Adventure, Drama, Science Ficti...
# 3    [Fight Club, Drama, edwardnorton, bradpitt, me...
# 4    [The Lord of the Rings: The Fellowship of the ...
# Name: mixed_credits, dtype: object
# 0    Inception Action Thriller Science Fiction Myst...
# 1    The Dark Knight Drama Action Crime Thriller ch...
# 2    Interstellar Adventure Drama Science Fiction m...
# 3    Fight Club Drama edwardnorton bradpitt meatloa...
# 4    The Lord of the Rings: The Fellowship of the R...
# Name: mixed_credits, dtype: object

# %%
# tf2 = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
# tfidf_matrix2 = tf2.fit_transform(df['mixed_credits'])
# tfidf_matrix2.shape

# %%
cosine_sim_mixed = cal_similarity_matrix(df['mixed_credits'])

# %%
get_recommendation_by_title(df, 'The Dark Knight', cosine_sim_mixed)
# Out:
#                            title  year  vote_count  vote_average popularity  \
# 0                      Inception  2010       14075             8  29.108149
# 2                   Interstellar  2014       11187             8  32.213481
# 20                  The Prestige  2006        4510             8   16.94556
# 24                       Memento  2000        4168             8  15.450789
# 75         The Dark Knight Rises  2012        9263             7   20.58258
# 83                 Batman Begins  2005        7511             7  28.505341
# 252                      Dunkirk  2017        2712             7  30.938854
# 776   Batman: Under the Red Hood  2010         459             7   7.039325
# 1041              Batman Returns  1992        1706             6  15.001681
# 1204                    Insomnia  2002        1181             6  11.424974
#
#                                                  genres  weighted_rating  \
# 0     [Action, Thriller, Science Fiction, Mystery, A...         7.917588
# 2                   [Adventure, Drama, Science Fiction]         7.897107
# 20                           [Drama, Mystery, Thriller]         7.758148
# 24                                  [Mystery, Thriller]         7.740175
# 75                     [Action, Crime, Drama, Thriller]         6.921448
# 83                               [Action, Crime, Drama]         6.904127
# 252             [Action, Drama, History, Thriller, War]         6.757878
# 776                                 [Action, Animation]         6.147016
# 1041                                  [Action, Fantasy]         5.846862
# 1204                         [Crime, Mystery, Thriller]         5.797081
#
#                                                 tagline  \
# 0                  Your mind is the scene of the crime.
# 2     Mankind was born on Earth. It was never meant ...
# 20                            Are You Watching Closely?
# 24                    Some memories are best forgotten.
# 75                                      The Legend Ends
# 83                               Evil fears the knight.
# 252                     The event that shaped our world
# 776                      Dare to Look Beneath the Hood.
# 1041                     The Bat, the Cat, the Penguin.
# 1204  A tough cop. A brilliant killer. An unspeakabl...
#
#                                                overview      id  \
# 0     Cobb, a skilled thief who commits corporate es...   27205
# 2     Interstellar chronicles the adventures of a gr...  157336
# 20    A mysterious story of two magicians whose inte...    1124
# 24    Suffering short-term memory loss after a head ...      77
# 75    Following the death of District Attorney Harve...   49026
# 83    Driven by tragedy, billionaire Bruce Wayne ded...     272
# 252   The miraculous evacuation of Allied soldiers f...  374720
# 776   Batman faces his ultimate challenge as the mys...   40662
# 1041  Having defeated the Joker, Batman now faces th...     364
# 1204  Two Los Angeles homicide detectives are dispat...     320
#
#                                             description  \
# 0     Cobb, a skilled thief who commits corporate es...
# 2     Interstellar chronicles the adventures of a gr...
# 20    A mysterious story of two magicians whose inte...
# 24    Suffering short-term memory loss after a head ...
# 75    Following the death of District Attorney Harve...
# 83    Driven by tragedy, billionaire Bruce Wayne ded...
# 252   The miraculous evacuation of Allied soldiers f...
# 776   Batman faces his ultimate challenge as the mys...
# 1041  Having defeated the Joker, Batman now faces th...
# 1204  Two Los Angeles homicide detectives are dispat...
#
#                                                    cast  \
# 0     [leonardodicaprio, josephgordon-levitt, ellenp...
# 2     [matthewmcconaughey, jessicachastain, annehath...
# 20           [hughjackman, christianbale, michaelcaine]
# 24          [guypearce, carrie-annemoss, joepantoliano]
# 75            [christianbale, michaelcaine, garyoldman]
# 83            [christianbale, michaelcaine, liamneeson]
# 252       [fionnwhitehead, tomglynn-carney, jacklowden]
# 776   [brucegreenwood, jensenackles, neilpatrickharris]
# 1041     [michaelkeaton, dannydevito, michellepfeiffer]
# 1204             [alpacino, robinwilliams, hilaryswank]
#
#                                                    crew  \
# 0     [{'credit_id': '56e8462cc3a368408400354c', 'de...
# 2     [{'credit_id': '54cba75b925141678e014d1a', 'de...
# 20    [{'credit_id': '52fe42e8c3a36847f802bef9', 'de...
# 24    [{'credit_id': '52fe4214c3a36847f80024cb', 'de...
# 75    [{'credit_id': '52fe4781c3a36847f81398c3', 'de...
# 83    [{'credit_id': '52fe4230c3a36847f800ac6d', 'de...
# 252   [{'credit_id': '598138b5925141519b008a5e', 'de...
# 776   [{'credit_id': '589f8b1ac3a3684fe40031cb', 'de...
# 1041  [{'credit_id': '52fe423cc3a36847f800e513', 'de...
# 1204  [{'credit_id': '52fe4237c3a36847f800ced5', 'de...
#
#                                                keywords          director  \
# 0     [lossoflov, dream, kidnap, sleep, subconsci, h...  christophernolan
# 2     [savingtheworld, artificialintellig, fatherson...  christophernolan
# 20    [competit, secret, obsess, magic, dyinganddeat...  christophernolan
# 24    [individu, insulin, tattoo, waitress, amnesia,...  christophernolan
# 75    [dccomic, crimefight, terrorist, secretident, ...  christophernolan
# 83    [himalaya, martialart, dccomic, crimefight, se...  christophernolan
# 252   [franc, beach, worldwarii, evacu, german, pilo...  christophernolan
# 776   [martialart, dccomic, vigilant, joker, superhe...     brandonvietti
# 1041  [holiday, corrupt, doublelif, dccomic, crimefi...         timburton
# 1204  [detect, confess, fbi, homicid, blackmail, sus...  christophernolan
#
#                                           mixed_credits
# 0     Inception Action Thriller Science Fiction Myst...
# 2     Interstellar Adventure Drama Science Fiction m...
# 20    The Prestige Drama Mystery Thriller hughjackma...
# 24    Memento Mystery Thriller guypearce carrie-anne...
# 75    The Dark Knight Rises Action Crime Drama Thril...
# 83    Batman Begins Action Crime Drama christianbale...
# 252   Dunkirk Action Drama History Thriller War fion...
# 776   Batman: Under the Red Hood Action Animation br...
# 1041  Batman Returns Action Fantasy michaelkeaton da...
# 1204  Insomnia Crime Mystery Thriller alpacino robin...

# %%
from surprise import Reader, Dataset, SVD, evaluate, NormalPredictor
from surprise.model_selection import cross_validate

# %%
svd = SVD()

# %%
ratings = pd.read_csv('./data/ratings_small.csv')

# %%
print(ratings.shape)
# ratings_small = ratings.sample(frac=0.1, random_state=1)
# Out:
# (100004, 4)

# %%
reader = Reader()
data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader)
data.split(n_folds=5)

# %%
cross_validate(svd, data, measures=['RMSE', 'MAE'])
# Out:
# {'test_rmse': array([0.89851619, 0.89890566, 0.89223992, 0.8920031 , 0.89562752]),
#  'test_mae': array([0.69141734, 0.6903456 , 0.68783327, 0.68717523, 0.69059357]),
#  'fit_time': (6.602980852127075,
#   6.42930006980896,
#   6.5155792236328125,
#   6.4863221645355225,
#   6.680490016937256),
#  'test_time': (0.2040572166442871,
#   0.19883179664611816,
#   0.20395994186401367,
#   0.20009589195251465,
#   0.20800995826721191)}

# %%
svd.fit(data.build_full_trainset())

# %%
print(ratings_small[ratings_small['userId'] == 1])
svd.predict(1, 302)
# help(svd.predict)
# Out:
#     userId  movieId  rating   timestamp
# 0        1       31     2.5  1260759144
# 1        1     1029     3.0  1260759179
# 2        1     1061     3.0  1260759182
# 3        1     1129     2.0  1260759185
# 4        1     1172     4.0  1260759205
# 5        1     1263     2.0  1260759151
# 6        1     1287     2.0  1260759187
# 7        1     1293     2.0  1260759148
# 8        1     1339     3.5  1260759125
# 9        1     1343     2.0  1260759131
# 10       1     1371     2.5  1260759135
# 11       1     1405     1.0  1260759203
# 12       1     1953     4.0  1260759191
# 13       1     2105     4.0  1260759139
# 14       1     2150     3.0  1260759194
# 15       1     2193     2.0  1260759198
# 16       1     2294     2.0  1260759108
# 17       1     2455     2.5  1260759113
# 18       1     2968     1.0  1260759200
# 19       1     3671     3.0  1260759117
# Prediction(uid=1, iid=302, r_ui=None, est=2.6777265506516774, details={'was_impossible': False})

# %%
svd.predict(1, 1029)
# Out:
# Prediction(uid=1, iid=1029, r_ui=None, est=2.9411632209301097, details={'was_impossible': False})

# %%
def hybrid(df, u_id, movies):
    cosine_sim = cal_similarity_matrix(df['mixed_credits'])
    recommended_indices = set([])
    for movie in movies:
        rec_movies = get_recommendation_by_title(df, movie, cosine_sim, 10)
        for movie_id in rec_movies['id']:
            recommended_indices.add(movie_id)
    recommended = df[np.isin(df['id'], list(recommended_indices))]
    recommended['est'] = recommended['id'].apply(lambda x: SVDtuned.predict(u_id, x).est)
    recommended = recommended.sort_values('est', ascending=False)
    return recommended[['title', 'year', 'est', 'weighted_rating']]

# %%
hybrid(df, 1, ['Avatar'])
# Out:
# /Users/JCChiang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                            title  year       est  weighted_rating
# 166   Terminator 2: Judgment Day  1991  3.190379         6.838208
# 154                        Alien  1979  3.044287         6.847596
# 159      Star Trek Into Darkness  2013  2.675936         6.844959
# 574                    The Abyss  1989  2.675936         6.393539
# 1054                      Alien³  1992  2.675936         5.843797
# 1216                   True Lies  1994  2.675936         5.791530
# 2220             Alien: Covenant  2017  2.675936         5.034164
# 213                       Aliens  1986  2.648211         6.795018
# 169               The Terminator  1984  2.501843         6.835908
# 82                       Titanic  1997  2.356975         6.907153

# %%
hybrid(df, 300, ['Avatar'])
# Out:
# /Users/JCChiang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                            title  year       est  weighted_rating
# 154                        Alien  1979  4.171326         6.847596
# 166   Terminator 2: Judgment Day  1991  4.164268         6.838208
# 213                       Aliens  1986  4.071627         6.795018
# 159      Star Trek Into Darkness  2013  3.909307         6.844959
# 574                    The Abyss  1989  3.909307         6.393539
# 1054                      Alien³  1992  3.909307         5.843797
# 1216                   True Lies  1994  3.909307         5.791530
# 2220             Alien: Covenant  2017  3.909307         5.034164
# 169               The Terminator  1984  3.828091         6.835908
# 82                       Titanic  1997  3.804173         6.907153

# %%
hybrid(df, 2, ['Toy Story'])
# Out:
# /Users/JCChiang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                title  year       est  weighted_rating
# 848             Cars  2006  3.938250         5.925940
# 1273             Big  1988  3.553033         5.774921
# 146      Toy Story 3  2010  3.459827         6.851922
# 182      Toy Story 2  1999  3.459827         6.824813
# 226   The Lego Movie  2014  3.459827         6.786095
# 283             Hugo  2011  3.459827         6.710485
# 935     A Bug's Life  1998  3.459827         5.883500
# 1332   Monster House  2006  3.459827         5.756527
# 103   Monsters, Inc.  2001  3.334047         6.884308
# 2189          Cars 2  2011  3.169770         5.042143

# %%
# Out:
# Empty DataFrame
# Columns: [userId, movieId, rating]
# Index: []

# %%
SVDtuned.predict(1, 1029)
# Out:
# Prediction(uid=1, iid=1029, r_ui=None, est=2.803786237121764, details={'was_impossible': False})

# %%
## hybrid
def hybrid(df, u_id, movies):  
    cosine_sim = cal_similarity_matrix(df['mixed_credits'])
    recommended_indices = set([])
    for movie in movies:
        rec_movies = get_recommendation_by_title(df, movie, cosine_sim, 20)
        for movie_id in rec_movies['id']:
            recommended_indices.add(movie_id)
    recommended = df[np.isin(df['id'], list(recommended_indices))]
    recommended['est'] = recommended['id'].apply(lambda x: SVDtuned.predict(u_id, x).est)
    recommended['true-rating'] = recommended['id'].\
        apply(lambda x: ratings[np.logical_and(ratings['userId'] == u_id, ratings['movieId'] == x)].rating)
    return recommended.sort_values('est', ascending=False)[['title','year', 'est', 'true-rating', 'weighted_rating']]

# %%
hybrid(df, 3, ['Toy Story']).head(20)
# Out:
# /Users/JCChiang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'true-rating'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in set(self, item, value, check)
#    4242         try:
# -> 4243             loc = self.items.get_loc(item)
#    4244         except KeyError:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'true-rating'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-221-825f1d72c790> in <module>()
# ----> 1 hybrid(df, 3, ['Toy Story']).head(20)
#
# <ipython-input-217-1905a03a9f58> in hybrid(df, u_id, movies)
#       9     recommended = df[np.isin(df['id'], list(recommended_indices))]
#      10     recommended['est'] = recommended['id'].apply(lambda x: SVDtuned.predict(u_id, x).est)
# ---> 11     recommended['true-rating'] = recommended['id'].        apply(lambda x: ratings[np.logical_and(ratings['userId'] == u_id, ratings['movieId'] == x)].rating)
#      12     return recommended.sort_values('est', ascending=False)[['title','year', 'est', 'true-rating', 'weighted_rating']]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3117         else:
#    3118             # set column
# -> 3119             self._set_item(key, value)
#    3120
#    3121     def _setitem_slice(self, key, value):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3193         self._ensure_valid_index(value)
#    3194         value = self._sanitize_column(key, value)
# -> 3195         NDFrame._set_item(self, key, value)
#    3196
#    3197         # check if we are modifying a copy
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _set_item(self, key, value)
#    2598
#    2599     def _set_item(self, key, value):
# -> 2600         self._data.set(key, value)
#    2601         self._clear_item_cache()
#    2602
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in set(self, item, value, check)
#    4244         except KeyError:
#    4245             # This item wasn't present, just insert at end
# -> 4246             self.insert(len(self.items), item, value)
#    4247             return
#    4248
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in insert(self, loc, item, value, allow_duplicates)
#    4345
#    4346         block = make_block(values=value, ndim=self.ndim,
# -> 4347                            placement=slice(loc, loc + 1))
#    4348
#    4349         for blkno, count in _fast_count_smallints(self._blknos[loc:]):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3203                      placement=placement, dtype=dtype)
#    3204
# -> 3205     return klass(values, ndim=ndim, placement=placement)
#    3206
#    3207 # TODO: flexible with index=None and/or items=None
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in __init__(self, values, placement, ndim)
#     123             raise ValueError(
#     124                 'Wrong number of items passed {val}, placement implies '
# --> 125                 '{mgr}'.format(val=len(self.values), mgr=len(self.mgr_locs)))
#     126
#     127     def _check_ndim(self, values, ndim):
#
# ValueError: Wrong number of items passed 0, placement implies 1

# %%
get_recommendation_by_title(df, 'Toy Story', cosine_sim_mixed)
# Out:
#                     title  year  vote_count  vote_average popularity  \
# 103        Monsters, Inc.  2001        6150             7  26.419962
# 147           Toy Story 3  2010        4710             7   16.96647
# 183           Toy Story 2  1999        3914             7  17.547693
# 227        The Lego Movie  2014        3127             7  16.418133
# 285                  Hugo  2011        2197             7  14.046164
# 339   Hachi: A Dog's Tale  2009        1769             7   8.621359
# 852                  Cars  2006        3991             6  18.907948
# 940          A Bug's Life  1998        2379             6  16.869209
# 1279                  Big  1988        1022             6   9.562292
# 2205               Cars 2  2011        2088             5  13.693002
#
#                                                genres  weighted_rating  \
# 103                       [Animation, Comedy, Family]         6.884308
# 147                       [Animation, Family, Comedy]         6.851922
# 183                       [Animation, Comedy, Family]         6.824813
# 227   [Adventure, Animation, Comedy, Family, Fantasy]         6.786095
# 285                        [Adventure, Drama, Family]         6.710485
# 339                                   [Drama, Family]         6.654237
# 852            [Animation, Adventure, Comedy, Family]         5.925940
# 940            [Adventure, Animation, Comedy, Family]         5.883500
# 1279        [Fantasy, Drama, Comedy, Romance, Family]         5.774921
# 2205           [Animation, Family, Adventure, Comedy]         5.042143
#
#                                                 tagline  \
# 103                           We Scare Because We Care.
# 147                            No toy gets left behind.
# 183                                  The toys are back!
# 227          The story of a nobody who saved everybody.
# 285   One of the most legendary directors of our tim...
# 339   A true story of faith, devotion and undying love.
# 852              Ahhh... it's got that new movie smell.
# 940      An epic presentation of miniature proportions.
# 1279  You're Only Young Once But For Josh It Might J...
# 2205                                           Ka-ciao!
#
#                                                overview      id  \
# 103   James Sullivan and Mike Wazowski are monsters,...     585
# 147   Woody, Buzz, and the rest of Andy's toys haven...   10193
# 183   Andy heads off to Cowboy Camp, leaving his toy...     863
# 227   An ordinary Lego mini-figure, mistakenly thoug...  137106
# 285   Hugo is an orphan boy living in the walls of a...   44826
# 339   A drama based on the true story of a college p...   28178
# 852   Lightning McQueen, a hotshot rookie race car d...     920
# 940   On behalf of "oppressed bugs everywhere," an i...    9487
# 1279  A young boy, Josh Baskin makes a wish at a car...    2280
# 2205  Star race car Lightning McQueen and his pal Ma...   49013
#
#                                             description  \
# 103   James Sullivan and Mike Wazowski are monsters,...
# 147   Woody, Buzz, and the rest of Andy's toys haven...
# 183   Andy heads off to Cowboy Camp, leaving his toy...
# 227   An ordinary Lego mini-figure, mistakenly thoug...
# 285   Hugo is an orphan boy living in the walls of a...
# 339   A drama based on the true story of a college p...
# 852   Lightning McQueen, a hotshot rookie race car d...
# 940   On behalf of "oppressed bugs everywhere," an i...
# 1279  A young boy, Josh Baskin makes a wish at a car...
# 2205  Star race car Lightning McQueen and his pal Ma...
#
#                                                    cast              crew  \
# 103              [johngoodman, billycrystal, marygibbs]      [petedocter]
# 147                     [tomhanks, timallen, nedbeatty]      [leeunkrich]
# 183                    [tomhanks, timallen, joancusack]    [johnlasseter]
# 227           [chrispratt, willferrell, elizabethbanks]        [phillord]
# 285      [benkingsley, sachabaroncohen, asabutterfield]  [martinscorsese]
# 339            [richardgere, joanallen, jasonalexander]  [lassehallström]
# 852                [owenwilson, paulnewman, bonniehunt]    [johnlasseter]
# 940   [kevinspacey, julialouis-dreyfus, haydenpanett...    [johnlasseter]
# 1279         [tomhanks, elizabethperkins, robertloggia]   [pennymarshall]
# 2205       [owenwilson, larrythecableguy, michaelcaine]    [johnlasseter]
#
#                                                keywords  \
# 103   [monster, infant, energysuppli, compani, rival...
# 147   [hostag, colleg, toy, barbi, anim, escap, dayc...
# 183   [museum, prosecut, identitycrisi, airplan, fle...
# 227   [fathersonrelationship, creativ, friendship, p...
# 285   [librari, clock, filmdirector, key, toy, boy, ...
# 339   [japanes, loyalti, humananimalrelationship, fr...
# 852   [carrac, carjourney, auto, route66, wrecker, p...
# 940   [winter, fight, ant, invent, collector, ant-hi...
# 1279  [basebal, co-work, bronx, pinballmachin, toyma...
# 2205  [carrac, sequel, comedi, anthropomorph, bestfr...
#
#                                           mixed_credits
# 103   Animation Comedy Family johngoodman billycryst...
# 147   Animation Family Comedy tomhanks timallen nedb...
# 183   Animation Comedy Family tomhanks timallen joan...
# 227   Adventure Animation Comedy Family Fantasy chri...
# 285   Adventure Drama Family benkingsley sachabaronc...
# 339   Drama Family richardgere joanallen jasonalexan...
# 852   Animation Adventure Comedy Family owenwilson p...
# 940   Adventure Animation Comedy Family kevinspacey ...
# 1279  Fantasy Drama Comedy Romance Family tomhanks e...
# 2205  Animation Family Adventure Comedy owenwilson l...
