# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
# read movie metadata
movie_md = pd.read_csv('./data/movies_metadata.csv', low_memory=False)

# %%
df = movie_md.copy()
df.shape
# Out:
# (45466, 24)

# %%
df.describe()
# Out:
#             revenue       runtime  vote_average    vote_count
# count  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   1.120935e+07     94.128199      5.618207    109.897338
# std    6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00    107.000000      6.800000     34.000000
# max    2.787965e+09   1256.000000     10.000000  14075.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
# adult                    45466 non-null object
# belongs_to_collection    4494 non-null object
# budget                   45466 non-null object
# genres                   45466 non-null object
# homepage                 7782 non-null object
# id                       45466 non-null object
# imdb_id                  45449 non-null object
# original_language        45455 non-null object
# original_title           45466 non-null object
# overview                 44512 non-null object
# popularity               45461 non-null object
# poster_path              45080 non-null object
# production_companies     45463 non-null object
# production_countries     45463 non-null object
# release_date             45379 non-null object
# revenue                  45460 non-null float64
# runtime                  45203 non-null float64
# spoken_languages         45460 non-null object
# status                   45379 non-null object
# tagline                  20412 non-null object
# title                    45460 non-null object
# video                    45460 non-null object
# vote_average             45460 non-null float64
# vote_count               45460 non-null float64
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB

# %%
df.head(2)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                homepage    id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story   862  tt0114709                en
# 1                                   NaN  8844  tt0113497                en
#
#   original_title                                           overview  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...
# 1        Jumanji  When siblings Judy and Peter discover an encha...
#
#      ...     release_date      revenue runtime  \
# 0    ...       1995-10-30  373554033.0    81.0
# 1    ...       1995-12-15  262797249.0   104.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                      tagline      title  video vote_average  \
# 0                                        NaN  Toy Story  False          7.7
# 1  Roll the dice and unleash the excitement!    Jumanji  False          6.9
#
#   vote_count
# 0     5415.0
# 1     2413.0
#
# [2 rows x 24 columns]

# %%
from ast import literal_eval
def process_genres(df):
    '''
    process genres column using liter_eval to convert string to python object
    extract the genres info
    '''
    df['genres'] = df['genres'].fillna('[]').apply(literal_eval)
    # extract the 'name' value of genres
    df['genres'] = df['genres'].apply(lambda x: [i['name'] for i in x])
    
print(df['genres'][0])
process_genres(df)
print(df['genres'][0])
# Out:
# [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]
# ['Animation', 'Comedy', 'Family']

# %%
# process release_date
df['year'] = df['release_date'].apply(lambda x: str(x)[:4] if x != 'NaN' else np.nan)
df['year'].head(1)
# Out:
# 0    1995
# Name: year, dtype: object

# %%
def process_vote(df, vote_count_cutoff_percentile=0.95):
    '''
    calculate weighted rating instead of row rating
    weighted rating (WR) = (v ÷ (v+m)) × R + (m ÷ (v+m)) × C

    Where: 
    R = average for the movie (mean) = (rating)
    v = number of votes for the movie = (votes)
    m = minimum votes required to be listed in the Top Rated list (default: 95 percentile of vote_count)
    C = the mean vote across the whole report
    '''
    df = df.dropna(subset=['vote_count', 'vote_average'])
    df.vote_count = df.vote_count.astype('int')
    df.vote_average = df.vote_average.astype('int')
    
    mean_vote_average = df.vote_average.mean()
    vote_count_cutoff = df.vote_count.quantile(vote_count_cutoff_percentile)
    df = df.loc[df['vote_count'] >= vote_count_cutoff]
    df['weighted_rating'] = (df.vote_average * df.vote_count/(df.vote_count + vote_count_cutoff)) + \
                            (mean_vote_average * vote_count_cutoff/(df.vote_count + vote_count_cutoff))
    df = df.sort_values('weighted_rating', ascending=False)
    return df

# %%
df = process_vote(df)
# Out:
# /Users/JCChiang/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
FEATURES = ['title', 'year', 'vote_count', 'vote_average', 'popularity', 'genres', 'weighted_rating', 'tagline', 'overview', 'id']
df = df[FEATURES]
df.shape
# Out:
# (2274, 10)

# %%
def get_tops_by_genres(df, *genres, intersect=True, top=10):
    if not genres:
        return df.head(top)
    elif not intersect:
        return df[df['genres'].apply(lambda x: not set(genres).isdisjoint(x))].head(top)
    else:
        return df[df['genres'].apply(lambda x: set(genres).issubset(x))].head(top)

# %%
get_tops_by_genres(df, 'Family')
# Out:
#                                           title  year  vote_count  \
# 1225                         Back to the Future  1985        6239
# 359                               The Lion King  1994        5520
# 5481                              Spirited Away  2001        3968
# 5833                         My Neighbor Totoro  1988        1730
# 926                       It's a Wonderful Life  1946        1103
# 19901                                  Paperman  2012         734
# 4766   Harry Potter and the Philosopher's Stone  2001        7188
# 13724                                        Up  2009        7048
# 30315                                Inside Out  2015        6737
# 15472                             Despicable Me  2010        6595
#
#        vote_average popularity                                        genres  \
# 1225              8  25.778509  [Adventure, Comedy, Science Fiction, Family]
# 359               8  21.605761                    [Family, Animation, Drama]
# 5481              8  41.048867       [Fantasy, Adventure, Animation, Family]
# 5833              8  13.507299                  [Fantasy, Animation, Family]
# 926               8  15.031588                      [Drama, Family, Fantasy]
# 19901             8   7.198633                  [Animation, Family, Romance]
# 4766              7  38.187238                  [Adventure, Fantasy, Family]
# 13724             7  19.330884        [Animation, Comedy, Family, Adventure]
# 30315             7  23.985587            [Drama, Comedy, Animation, Family]
# 15472             7  22.274502                           [Animation, Family]
#
#        weighted_rating                                            tagline  \
# 1225          7.820813  He's the only kid ever to get into trouble bef...
# 359           7.799175  Life's greatest adventure is finding your plac...
# 5481          7.728370     The tunnel led Chihiro to a mysterious town...
# 5833          7.447452  These strange creatures still exist in Japan. ...
# 926           7.222046     It's a wonderful laugh! It's a wonderful love!
# 19901         6.976272                      Delicate, charming and sweet.
# 4766          6.900064                               Let the Magic Begin.
# 13724         6.898194                                                NaN
# 30315         6.893778           Meet the little voices inside your head.
# 15472         6.891633                                Superbad. Superdad.
#
#                                                 overview      id
# 1225   Eighties teenager Marty McFly is accidentally ...     105
# 359    A young lion cub named Simba can't wait to be ...    8587
# 5481   A ten year old girl who wanders away from her ...     129
# 5833   Two sisters move to the country with their fat...    8392
# 926    George Bailey has spent his entire life giving...    1585
# 19901  An urban office worker finds that paper airpla...  140420
# 4766   Harry Potter has lived under the stairs at his...     671
# 13724  Carl Fredricksen spent his entire life dreamin...   14160
# 30315  Growing up can be a bumpy road, and it's no ex...  150540
# 15472  Villainous Gru lives up to his reputation as a...   20352

# %%
get_tops_by_genres(df, 'Family', 'Animation')
# Out:
#                     title  year  vote_count  vote_average  popularity  \
# 359         The Lion King  1994        5520             8   21.605761
# 5481        Spirited Away  2001        3968             8   41.048867
# 5833   My Neighbor Totoro  1988        1730             8   13.507299
# 19901            Paperman  2012         734             8    7.198633
# 13724                  Up  2009        7048             7   19.330884
# 30315          Inside Out  2015        6737             7   23.985587
# 15472       Despicable Me  2010        6595             7   22.274502
# 12704              WALL·E  2008        6439             7   16.088366
# 6232         Finding Nemo  2003        6292             7   25.497794
# 24455          Big Hero 6  2014        6289             7  213.849907
#
#                                                genres  weighted_rating  \
# 359                        [Family, Animation, Drama]         7.799175
# 5481          [Fantasy, Adventure, Animation, Family]         7.728370
# 5833                     [Fantasy, Animation, Family]         7.447452
# 19901                    [Animation, Family, Romance]         6.976272
# 13724          [Animation, Comedy, Family, Adventure]         6.898194
# 30315              [Drama, Comedy, Animation, Family]         6.893778
# 15472                             [Animation, Family]         6.891633
# 12704                             [Animation, Family]         6.889173
# 6232                              [Animation, Family]         6.886751
# 24455  [Adventure, Family, Animation, Action, Comedy]         6.886700
#
#                                                  tagline  \
# 359    Life's greatest adventure is finding your plac...
# 5481      The tunnel led Chihiro to a mysterious town...
# 5833   These strange creatures still exist in Japan. ...
# 19901                      Delicate, charming and sweet.
# 13724                                                NaN
# 30315           Meet the little voices inside your head.
# 15472                                Superbad. Superdad.
# 12704                 An adventure beyond the ordinar-E.
# 6232   There are 3.7 trillion fish in the ocean. They...
# 24455     From the creators of Wreck-it Ralph and Frozen
#
#                                                 overview      id
# 359    A young lion cub named Simba can't wait to be ...    8587
# 5481   A ten year old girl who wanders away from her ...     129
# 5833   Two sisters move to the country with their fat...    8392
# 19901  An urban office worker finds that paper airpla...  140420
# 13724  Carl Fredricksen spent his entire life dreamin...   14160
# 30315  Growing up can be a bumpy road, and it's no ex...  150540
# 15472  Villainous Gru lives up to his reputation as a...   20352
# 12704  WALL·E is the last robot left on an Earth that...   10681
# 6232   Nemo, an adventurous young clownfish, is unexp...      12
# 24455  The special bond that develops between plus-si...  177572

# %%
get_tops_by_genres(df, 'Family', 'Animation', intersect=True)
# Out:
#                     title  year  vote_count  vote_average  popularity  \
# 359         The Lion King  1994        5520             8   21.605761
# 5481        Spirited Away  2001        3968             8   41.048867
# 5833   My Neighbor Totoro  1988        1730             8   13.507299
# 19901            Paperman  2012         734             8    7.198633
# 13724                  Up  2009        7048             7   19.330884
# 30315          Inside Out  2015        6737             7   23.985587
# 15472       Despicable Me  2010        6595             7   22.274502
# 12704              WALL·E  2008        6439             7   16.088366
# 6232         Finding Nemo  2003        6292             7   25.497794
# 24455          Big Hero 6  2014        6289             7  213.849907
#
#                                                genres  weighted_rating  \
# 359                        [Family, Animation, Drama]         7.799175
# 5481          [Fantasy, Adventure, Animation, Family]         7.728370
# 5833                     [Fantasy, Animation, Family]         7.447452
# 19901                    [Animation, Family, Romance]         6.976272
# 13724          [Animation, Comedy, Family, Adventure]         6.898194
# 30315              [Drama, Comedy, Animation, Family]         6.893778
# 15472                             [Animation, Family]         6.891633
# 12704                             [Animation, Family]         6.889173
# 6232                              [Animation, Family]         6.886751
# 24455  [Adventure, Family, Animation, Action, Comedy]         6.886700
#
#                                                  tagline  \
# 359    Life's greatest adventure is finding your plac...
# 5481      The tunnel led Chihiro to a mysterious town...
# 5833   These strange creatures still exist in Japan. ...
# 19901                      Delicate, charming and sweet.
# 13724                                                NaN
# 30315           Meet the little voices inside your head.
# 15472                                Superbad. Superdad.
# 12704                 An adventure beyond the ordinar-E.
# 6232   There are 3.7 trillion fish in the ocean. They...
# 24455     From the creators of Wreck-it Ralph and Frozen
#
#                                                 overview      id
# 359    A young lion cub named Simba can't wait to be ...    8587
# 5481   A ten year old girl who wanders away from her ...     129
# 5833   Two sisters move to the country with their fat...    8392
# 19901  An urban office worker finds that paper airpla...  140420
# 13724  Carl Fredricksen spent his entire life dreamin...   14160
# 30315  Growing up can be a bumpy road, and it's no ex...  150540
# 15472  Villainous Gru lives up to his reputation as a...   20352
# 12704  WALL·E is the last robot left on an Earth that...   10681
# 6232   Nemo, an adventurous young clownfish, is unexp...      12
# 24455  The special bond that develops between plus-si...  177572

# %%
def get_tops_by_year(df, year, top=10):
    return df[df.year == str(year)].head(top)

# %%
get_tops_by_year(df,2013)
# Out:
#                                      title  year  vote_count  vote_average  \
# 22131              The Wolf of Wall Street  2013        6768             7
# 22058      The Hunger Games: Catching Fire  2013        6656             7
# 21592                              Gravity  2013        5879             7
# 21025                       Now You See Me  2013        5635             7
# 22110                               Frozen  2013        5440             7
# 21161                      Despicable Me 2  2013        4729             7
# 22059  The Hobbit: The Desolation of Smaug  2013        4633             7
# 20922              Star Trek Into Darkness  2013        4479             7
# 22168                                  Her  2013        4215             7
# 20910                     The Great Gatsby  2013        3885             7
#
#       popularity                                genres  weighted_rating  \
# 22131  16.382422                [Crime, Drama, Comedy]         6.894236
# 22058  25.309139  [Adventure, Action, Science Fiction]         6.892565
# 21592   18.50194    [Science Fiction, Thriller, Drama]         6.879342
# 21025  17.852022                     [Thriller, Crime]         6.874491
# 22110  24.248243        [Animation, Adventure, Family]         6.870324
# 21161   24.82355           [Animation, Comedy, Family]         6.852467
# 22059  20.644776                  [Adventure, Fantasy]         6.849671
# 20922   15.78129  [Action, Adventure, Science Fiction]         6.844959
# 22168  13.829515     [Romance, Science Fiction, Drama]         6.836155
# 20910  17.598936                      [Drama, Romance]         6.823636
#
#                                                  tagline  \
# 22131                                EARN. SPEND. PARTY.
# 22058              Every revolution begins with a spark.
# 21592                                       Don't Let Go
# 21025  4 amazing magicians. 3 impossible heists. 1 bi...
# 22110  Only the act of true love will thaw a frozen h...
# 21161                                        Back 2 Work
# 22059  Beyond darkness... beyond desolation... lies t...
# 20922                                    Earth Will Fall
# 22168                           A Spike Jonze Love Story
# 20910  Reserving judgments is a matter of infinite ho...
#
#                                                 overview      id
# 22131  A New York stockbroker refuses to cooperate in...  106646
# 22058  Katniss Everdeen has returned home safe after ...  101299
# 21592  Dr. Ryan Stone, a brilliant medical engineer o...   49047
# 21025  An FBI agent and an Interpol detective track a...   75656
# 22110  Young princess Anna of Arendelle dreams about ...  109445
# 21161  Gru is recruited by the Anti-Villain League to...   93456
# 22059  The Dwarves, Bilbo and Gandalf have successful...   57158
# 20922  When the crew of the Enterprise is called back...   54138
# 22168  In the not so distant future, Theodore, a lone...  152601
# 20910  An adaptation of F. Scott Fitzgerald's Long Is...   64682

# %%
df.columns
# Out:
# Index(['title', 'year', 'vote_count', 'vote_average', 'popularity', 'genres',
#        'weighted_rating', 'tagline', 'overview', 'id'],
#       dtype='object')

# %%
# Content-based recommendation
df.tagline.fillna('', inplace=True)
df.overview.fillna('', inplace=True)

# %%
df['description'] = df.overview + df.tagline
df['description'].head(1).values
# Out:
# array(['Cobb, a skilled thief who commits corporate espionage by infiltrating the subconscious of his targets is offered a chance to regain his old life as payment for a task considered to be impossible: "inception", the implantation of another person\'s idea into a target\'s subconscious.Your mind is the scene of the crime.'],
#       dtype=object)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(df['description'])
tfidf_matrix.shape
# Out:
# (2274, 75685)

# %%
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
cosine_sim_description = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
title_to_idx = {title: idx for title, idx in zip(df.title, range(df.shape[0]))}
title_to_idx['Inception']
# Out:
# 0

# %%
def get_recommendation_by_title(df, title, cosine_sim, top=10):
    idx = title_to_idx[title]
    scores = sorted(list(enumerate(cosine_sim[idx])), key=lambda x: x[1], reverse=True)
    movie_indices = list(map(lambda x: x[0], scores[1:top+1]))
    return df.iloc[movie_indices].sort_values('weighted_rating', ascending=False)

# %%
get_recommendation_by_title(df, 'Toy Story', cosine_sim_description)
# Out:
#                                                   title  year  vote_count  \
# 146                                     Despicable Me 2  2013        4729
# 182                                 Catch Me If You Can  2002        3917
# 218                     The Secret Life of Walter Mitty  2013        3213
# 458                                     The Bucket List  2007        1138
# 688                                              John Q  2002         604
# 783                                                Once  2007         457
# 977   Percy Jackson & the Olympians: The Lightning T...  2010        2079
# 1639                                You Only Live Twice  1967         541
# 1774                      Nanny McPhee and the Big Bang  2010         450
# 1843                    Garfield: A Tail of Two Kitties  2006         477
#
#       vote_average popularity                               genres  \
# 146              7   24.82355          [Animation, Comedy, Family]
# 182              7  19.833077                       [Drama, Crime]
# 218              7   8.684892  [Adventure, Comedy, Drama, Fantasy]
# 458              7   9.070643                      [Drama, Comedy]
# 688              7   8.867562             [Drama, Thriller, Crime]
# 783              7  10.357064              [Drama, Music, Romance]
# 977              6   9.785895         [Adventure, Fantasy, Family]
# 1639             6  10.359669        [Action, Thriller, Adventure]
# 1774             6   8.983275                    [Comedy, Fantasy]
# 1843             5   7.217377          [Animation, Comedy, Family]
#
#       weighted_rating                                            tagline  \
# 146          6.852467                                        Back 2 Work
# 182          6.824933                     The true story of a real fake.
# 218          6.791139                        Stop Dreaming, Start Living
# 458          6.515449                                      Find the joy.
# 688          6.266171  Give a father no options and you leave him no ...
# 783          6.145101            How often do you find the right person?
# 977          5.869592                                     Worlds Collide
# 1639         5.663882  You Only Live Twice...and Twice is the only wa...
# 1774         5.629282                  You'll Believe That Pigs Can Fly!
# 1843         5.116669                                The Ego has landed.
#
#                                                overview      id  \
# 146   Gru is recruited by the Anti-Villain League to...   93456
# 182   A true story about Frank Abagnale Jr. who, bef...     640
# 218   A timid magazine photo manager who lives life ...  116745
# 458   Corporate billionaire Edward Cole and working ...    7350
# 688   John Quincy Archibald is a father and husband ...    8470
# 783   A vacuum repairman moonlights as a street musi...    5723
# 977   Accident prone teenager, Percy discovers he's ...   32657
# 1639  A mysterious space craft kidnaps a Russian and...     667
# 1774  Nanny McPhee appears at the door of a harried ...   35019
# 1843  Garfield is back and this time Garfield and hi...    9513
#
#                                             description  \
# 146   Gru is recruited by the Anti-Villain League to...
# 182   A true story about Frank Abagnale Jr. who, bef...
# 218   A timid magazine photo manager who lives life ...
# 458   Corporate billionaire Edward Cole and working ...
# 688   John Quincy Archibald is a father and husband ...
# 783   A vacuum repairman moonlights as a street musi...
# 977   Accident prone teenager, Percy discovers he's ...
# 1639  A mysterious space craft kidnaps a Russian and...
# 1774  Nanny McPhee appears at the door of a harried ...
# 1843  Garfield is back and this time Garfield and hi...
#
#                                                    cast               crew  \
# 146           [stevecarell, kristenwiig, benjaminbratt]     [pierrecoffin]
# 182     [leonardodicaprio, tomhanks, christopherwalken]  [stevenspielberg]
# 218             [benstiller, kristenwiig, pattonoswalt]       [benstiller]
# 458           [jacknicholson, morganfreeman, seanhayes]        [robreiner]
# 688         [denzelwashington, robertduvall, anneheche]   [nickcassavetes]
# 783            [glenhansard, markétairglová, hughwalsh]       [johncarney]
# 977   [loganlerman, brandont.jackson, alexandradadda...    [chriscolumbus]
# 1639          [seanconnery, akikowakabayashi, karindor]     [lewisgilbert]
# 1774       [emmathompson, asabutterfield, ralphfiennes]     [susannawhite]
# 1843    [billmurray, jenniferlovehewitt, billyconnolly]          [timhill]
#
#                                                keywords  \
# 146   [secretag, bakeri, fallinginlov, fatherdaughte...
# 182   [conman, biographi, fbiagent, overheadcamerash...
# 218   [himalaya, photograph, magazin, iceland, daydr...
# 458   [africa, himalaya, braintumor, wifehusbandrela...
# 688   [fathersonrelationship, chicago, heartattack, ...
# 783   [rockandrol, pop, musicstyl, loveofone'slif, f...
# 977   [monster, greekmytholog, god, poseidon , light...
# 1639  [londonengland, japan, england, assassin, heli...
# 1774  [nanni, fantasi, children, aftercreditssting, ...
# 1843  [londonengland, cat, mistakeinperson, luxuri, ...
#
#                                           mixed_credits
# 146   Animation Comedy Family stevecarell kristenwii...
# 182   Drama Crime leonardodicaprio tomhanks christop...
# 218   Adventure Comedy Drama Fantasy benstiller kris...
# 458   Drama Comedy jacknicholson morganfreeman seanh...
# 688   Drama Thriller Crime denzelwashington robertdu...
# 783   Drama Music Romance glenhansard markétairglová...
# 977   Adventure Fantasy Family loganlerman brandont....
# 1639  Action Thriller Adventure seanconnery akikowak...
# 1774  Comedy Fantasy emmathompson asabutterfield ral...
# 1843  Animation Comedy Family billmurray jenniferlov...

# %%
get_recommendation_by_title(df, 'The Dark Knight', cosine_sim_description)
# Out:
#                               title  year  vote_count  vote_average  \
# 75            The Dark Knight Rises  2012        9263             7
# 175                        Die Hard  1988        4005             7
# 288                  Hidden Figures  2016        2178             7
# 382                     The Aviator  2004        1526             7
# 393                      Collateral  2004        1476             7
# 740        The Hundred-Foot Journey  2014         516             7
# 776       The Count of Monte Cristo  2002         463             7
# 1041                The Transporter  2002        1724             6
# 1724  Star Trek IV: The Voyage Home  1986         490             6
# 2158                  Dirty Grandpa  2016        1429             5
#
#      popularity                                genres  weighted_rating  \
# 75     20.58258      [Action, Crime, Drama, Thriller]         6.921448
# 175   16.640522                    [Action, Thriller]         6.828404
# 288   16.816834                               [Drama]         6.708379
# 382     9.86738                               [Drama]         6.611370
# 393   13.455112              [Drama, Crime, Thriller]         6.601196
# 740   14.466789                               [Drama]         6.198195
# 776   10.765924  [Action, Adventure, Drama, Thriller]         6.150820
# 1041  13.217421             [Action, Crime, Thriller]         5.848140
# 1724  12.596956          [Science Fiction, Adventure]         5.645330
# 2158  16.290586                              [Comedy]         5.057051
#
#                                                 tagline  \
# 75                                      The Legend Ends
# 175             40 Stories. Twelve Terrorists. One Cop.
# 288   Meet the women you don't know, behind the miss...
# 382   For some men, the sky was the limit. For him, ...
# 393                    It started like any other night.
# 740   Life's greatest journey begins with the first ...
# 776            Prepare for adventure. Count on revenge.
# 1041                       Rules are made to be broken.
# 1724  The key to saving the future can only be found...
# 2158  This is Jason. He's a little worried about his...
#
#                                                overview      id  \
# 75    Following the death of District Attorney Harve...   49026
# 175   NYPD cop, John McClane's plan to reconcile wit...     562
# 288   The untold story of Katherine G. Johnson, Doro...  381284
# 382   A biopic depicting the life of filmmaker and a...    2567
# 393   Cab driver Max picks up a man who offers him $...    1538
# 740   A story centered around an Indian family who m...  228194
# 776   Edmond Dantés's life and plans to marry the be...   11362
# 1041  Former Special Forces officer, Frank Martin wi...    4108
# 1724  Fugitives of the Federation for their daring r...     168
# 2158  Jason Kelly is one week away from marrying his...  291870
#
#                                             description  \
# 75    Following the death of District Attorney Harve...
# 175   NYPD cop, John McClane's plan to reconcile wit...
# 288   The untold story of Katherine G. Johnson, Doro...
# 382   A biopic depicting the life of filmmaker and a...
# 393   Cab driver Max picks up a man who offers him $...
# 740   A story centered around an Indian family who m...
# 776   Edmond Dantés's life and plans to marry the be...
# 1041  Former Special Forces officer, Frank Martin wi...
# 1724  Fugitives of the Federation for their daring r...
# 2158  Jason Kelly is one week away from marrying his...
#
#                                                    cast                crew  \
# 75            [christianbale, michaelcaine, garyoldman]  [christophernolan]
# 175        [brucewillis, alanrickman, alexandergodunov]     [johnmctiernan]
# 288      [tarajip.henson, octaviaspencer, janellemonae]     [theodoremelfi]
# 382   [leonardodicaprio, cateblanchett, katebeckinsale]    [martinscorsese]
# 393            [tomcruise, jamiefoxx, jadapinkettsmith]       [michaelmann]
# 740                  [helenmirren, manishdayal, ompuri]    [lassehallström]
# 776             [jimcaviezel, guypearce, richardharris]     [kevinreynolds]
# 1041            [jasonstatham, shuqi, françoisberléand]    [louisleterrier]
# 1724     [williamshatner, leonardnimoy, deforestkelley]      [leonardnimoy]
# 2158            [zacefron, robertdeniro, juliannehough]          [danmazer]
#
#                                                keywords  \
# 75    [dccomic, crimefight, terrorist, secretident, ...
# 175   [helicopt, journalist, basedonnovel, terrorist...
# 288   [nasa, sexism, biographi, mathemat, racialsegr...
# 382   [ladykil, pilot, biographi, woman, aviat, phob...
# 393   [california, taxi, assassin, hostag, taxidriv,...
# 740   [franc, basedonnovel, indianlead, restaur, fam...
# 776   [lossoflov, lover(female), ex-lov, tortur, nap...
# 1041       [carjourney, transport, auto, humantraffick]
# 1724  [savingtheworld, sanfrancisco, ussenterprise-a...
# 2158  [grandfathergrandsonrelationship, grandfath, r...
#
#                                           mixed_credits
# 75    Action Crime Drama Thriller christianbale mich...
# 175   Action Thriller brucewillis alanrickman alexan...
# 288   Drama tarajip.henson octaviaspencer janellemon...
# 382   Drama leonardodicaprio cateblanchett katebecki...
# 393   Drama Crime Thriller tomcruise jamiefoxx jadap...
# 740   Drama helenmirren manishdayal ompuri lassehall...
# 776   Action Adventure Drama Thriller jimcaviezel gu...
# 1041  Action Crime Thriller jasonstatham shuqi franç...
# 1724  Science Fiction Adventure williamshatner leona...
# 2158  Comedy zacefron robertdeniro juliannehough dan...

# %%
# add more features to calculate similarity between movies
credits = pd.read_csv('./data/credits.csv')
keywords = pd.read_csv('./data/keywords.csv')

# %%
df['id'] = df['id'].astype(int)
df = df.merge(credits, on='id')
df = df.merge(keywords, on='id')

# %%
# extract names of the top 3 actors from the cast column
df['cast'] = df['cast'].fillna('[]').apply(lambda x: [str.lower(i['name'].replace(" ","")) for i in literal_eval(x)][:3])

# %%
def get_director(x):
    '''
    extract director's name from crew column of x
    '''
    for i in x:
        if i['job'] == 'Director':
            return [str.lower(i['name'].replace(' ', ''))]
    return np.nan

# %%
df['crew'] = df['crew'].fillna('[]').apply(lambda x: get_director(literal_eval(x)))

# %%
# process keywords
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer('english')
df['keywords'] = df['keywords'].fillna('[]').apply(lambda x: [str.lower(stemmer.stem(i['name'].replace(' ', ''))) for i in literal_eval(x)])

# %%
df.head()[['cast', 'crew', 'keywords']]
# Out:
#                                                 cast                crew  \
# 0  [leonardodicaprio, josephgordon-levitt, ellenp...  [christophernolan]
# 1         [christianbale, michaelcaine, heathledger]  [christophernolan]
# 2  [matthewmcconaughey, jessicachastain, annehath...  [christophernolan]
# 3                 [edwardnorton, bradpitt, meatloaf]      [davidfincher]
# 4           [elijahwood, ianmckellen, cateblanchett]      [peterjackson]
#
#                                             keywords
# 0  [lossoflov, dream, kidnap, sleep, subconsci, h...
# 1  [dccomic, crimefight, secretident, scarecrow, ...
# 2  [savingtheworld, artificialintellig, fatherson...
# 3  [supportgroup, dualident, nihil, rageandh, ins...
# 4  [elv, dwarv, orc, middle-earth(tolkien), hobbi...

# %%
# use genres, top 3 actors, director (* 3 to make director a more significant factor), 
# and keyword to calculate similarity
df['mixed_credits'] = df['genres'] + df['cast'] + df['crew'] * 3 + df['keywords']
df.head(1)
df['mixed_credits'] = df['mixed_credits'].apply(lambda x: ' '.join(x))

# %%
tf2 = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
tfidf_matrix2 = tf2.fit_transform(df['mixed_credits'])
tfidf_matrix2.shape
# Out:
# (2291, 41948)

# %%
cosine_sim_mixed = cosine_similarity(tfidf_matrix2, tfidf_matrix2)

# %%
get_recommendation_by_title(df, 'The Dark Knight', cosine_sim_mixed)
# Out:
#                            title  year  vote_count  vote_average popularity  \
# 0                      Inception  2010       14075             8  29.108149
# 2                   Interstellar  2014       11187             8  32.213481
# 20                  The Prestige  2006        4510             8   16.94556
# 24                       Memento  2000        4168             8  15.450789
# 75         The Dark Knight Rises  2012        9263             7   20.58258
# 83                 Batman Begins  2005        7511             7  28.505341
# 253                      Dunkirk  2017        2712             7  30.938854
# 780   Batman: Under the Red Hood  2010         459             7   7.039325
# 1046              Batman Returns  1992        1706             6  15.001681
# 1210                    Insomnia  2002        1181             6  11.424974
#
#                                                  genres  weighted_rating  \
# 0     [Action, Thriller, Science Fiction, Mystery, A...         7.917588
# 2                   [Adventure, Drama, Science Fiction]         7.897107
# 20                           [Drama, Mystery, Thriller]         7.758148
# 24                                  [Mystery, Thriller]         7.740175
# 75                     [Action, Crime, Drama, Thriller]         6.921448
# 83                               [Action, Crime, Drama]         6.904127
# 253             [Action, Drama, History, Thriller, War]         6.757878
# 780                                 [Action, Animation]         6.147016
# 1046                                  [Action, Fantasy]         5.846862
# 1210                         [Crime, Mystery, Thriller]         5.797081
#
#                                                 tagline  \
# 0                  Your mind is the scene of the crime.
# 2     Mankind was born on Earth. It was never meant ...
# 20                            Are You Watching Closely?
# 24                    Some memories are best forgotten.
# 75                                      The Legend Ends
# 83                               Evil fears the knight.
# 253                     The event that shaped our world
# 780                      Dare to Look Beneath the Hood.
# 1046                     The Bat, the Cat, the Penguin.
# 1210  A tough cop. A brilliant killer. An unspeakabl...
#
#                                                overview      id  \
# 0     Cobb, a skilled thief who commits corporate es...   27205
# 2     Interstellar chronicles the adventures of a gr...  157336
# 20    A mysterious story of two magicians whose inte...    1124
# 24    Suffering short-term memory loss after a head ...      77
# 75    Following the death of District Attorney Harve...   49026
# 83    Driven by tragedy, billionaire Bruce Wayne ded...     272
# 253   The miraculous evacuation of Allied soldiers f...  374720
# 780   Batman faces his ultimate challenge as the mys...   40662
# 1046  Having defeated the Joker, Batman now faces th...     364
# 1210  Two Los Angeles homicide detectives are dispat...     320
#
#                                             description  \
# 0     Cobb, a skilled thief who commits corporate es...
# 2     Interstellar chronicles the adventures of a gr...
# 20    A mysterious story of two magicians whose inte...
# 24    Suffering short-term memory loss after a head ...
# 75    Following the death of District Attorney Harve...
# 83    Driven by tragedy, billionaire Bruce Wayne ded...
# 253   The miraculous evacuation of Allied soldiers f...
# 780   Batman faces his ultimate challenge as the mys...
# 1046  Having defeated the Joker, Batman now faces th...
# 1210  Two Los Angeles homicide detectives are dispat...
#
#                                                    cast                crew  \
# 0     [leonardodicaprio, josephgordon-levitt, ellenp...  [christophernolan]
# 2     [matthewmcconaughey, jessicachastain, annehath...  [christophernolan]
# 20           [hughjackman, christianbale, michaelcaine]  [christophernolan]
# 24          [guypearce, carrie-annemoss, joepantoliano]  [christophernolan]
# 75            [christianbale, michaelcaine, garyoldman]  [christophernolan]
# 83            [christianbale, michaelcaine, liamneeson]  [christophernolan]
# 253       [fionnwhitehead, tomglynn-carney, jacklowden]  [christophernolan]
# 780   [brucegreenwood, jensenackles, neilpatrickharris]     [brandonvietti]
# 1046     [michaelkeaton, dannydevito, michellepfeiffer]         [timburton]
# 1210             [alpacino, robinwilliams, hilaryswank]  [christophernolan]
#
#                                                keywords  \
# 0     [lossoflov, dream, kidnap, sleep, subconsci, h...
# 2     [savingtheworld, artificialintellig, fatherson...
# 20    [competit, secret, obsess, magic, dyinganddeat...
# 24    [individu, insulin, tattoo, waitress, amnesia,...
# 75    [dccomic, crimefight, terrorist, secretident, ...
# 83    [himalaya, martialart, dccomic, crimefight, se...
# 253   [franc, beach, worldwarii, evacu, german, pilo...
# 780   [martialart, dccomic, vigilant, joker, superhe...
# 1046  [holiday, corrupt, doublelif, dccomic, crimefi...
# 1210  [detect, confess, fbi, homicid, blackmail, sus...
#
#                                           mixed_credits
# 0     Action Thriller Science Fiction Mystery Advent...
# 2     Adventure Drama Science Fiction matthewmcconau...
# 20    Drama Mystery Thriller hughjackman christianba...
# 24    Mystery Thriller guypearce carrie-annemoss joe...
# 75    Action Crime Drama Thriller christianbale mich...
# 83    Action Crime Drama christianbale michaelcaine ...
# 253   Action Drama History Thriller War fionnwhitehe...
# 780   Action Animation brucegreenwood jensenackles n...
# 1046  Action Fantasy michaelkeaton dannydevito miche...
# 1210  Crime Mystery Thriller alpacino robinwilliams ...
